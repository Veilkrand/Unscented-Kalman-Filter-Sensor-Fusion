# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

file="NIS_radar.txt"
#file="NIS_lidar.txt"

nis=loadtxt(file, dtype=float, delimiter="/n", unpack=False)

x = np.array(range(1,nis.shape[0]+1))

plt.plot(x, nis)
plt.title('Radar NIS')
plt.show()

# %%
file="NIS_lidar.txt"
#file="NIS_lidar.txt"

nis=loadtxt(file, dtype=float, delimiter="/n", unpack=False)

x = np.array(range(1,nis.shape[0]+1))

plt.plot(x, nis)
plt.title('Lidar NIS')
plt.show()
